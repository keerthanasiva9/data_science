# %% [markdown]
# # NORMALIZATION AND OPTIMIZATION

# %% [markdown]
# We are organizing the attributes and tables of a relational database to minimize data redundancy.
# Normalization involves refactoring a table into smaller (and less redundant) tables but without losing
# information; defining foreign keys in the old table referencing the primary keys of the new ones. The
# objective is to isolate data so that additions, deletions, and modifications of an attribute can be made in
# just one table and then propagated through the rest of the database using the defined foreign keys.

# %% [markdown]
# ## Imdb table
# Firstly we are taking the base table, which consists of 50 most popular crime movies. We are normalizing the table up till 1NF, 2NF and 3NF.
#
#  1NF - The table has multiple values in the genre column. We have seperated the genres into different rows, so that it satisfies 1NF.
#
#  2NF - Once we seperated the genres into different rows, we are now having repetitions in the movie_names column. This can be avoided by creating another column in the base table called Movie_ID and taking out the genre column from the base table and creating another table which has Movie_ID and genre names. This will satisfy 2NF.
#
#  3NF - The table has certificate column as a transitive dependancy, so we will be creating another table which includes the certificate column and give IDs for each certifications. We will then replace the certifcations with their IDs assigned. This will satisfy the 3NF.

# %% [markdown]
# ![Screen%20Shot%202019-03-25%20at%2012.54.57%20PM.png](attachment:Screen%20Shot%202019-03-25%20at%2012.54.57%20PM.png)

# %% [markdown]
# 1NF:

# %% [markdown]
# insert into movie_genre(movie_id,genre) select movie_id,genre from imdb_movies;

# %% [markdown]
# ![Screen%20Shot%202019-03-25%20at%201.33.18%20PM.png](attachment:Screen%20Shot%202019-03-25%20at%201.33.18%20PM.png)

# %% [markdown]
# 2 NF

# %% [markdown]
# ![Screen%20Shot%202019-03-25%20at%201.34.23%20PM.png](attachment:Screen%20Shot%202019-03-25%20at%201.34.23%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202019-03-25%20at%201.35.59%20PM.png](attachment:Screen%20Shot%202019-03-25%20at%201.35.59%20PM.png)

# %% [markdown]
# 3NF:

# %% [markdown]
# Table 1:

# %% [markdown]
# ![Screen%20Shot%202019-03-25%20at%202.57.09%20PM.png](attachment:Screen%20Shot%202019-03-25%20at%202.57.09%20PM.png)

# %% [markdown]
# Table 2:

# %% [markdown]
# ![Screen%20Shot%202019-03-25%20at%202.46.06%20PM.png](attachment:Screen%20Shot%202019-03-25%20at%202.46.06%20PM.png)

# %% [markdown]
# Table 3:

# %% [markdown]
# ![Screen%20Shot%202019-03-25%20at%201.35.59%20PM.png](attachment:Screen%20Shot%202019-03-25%20at%201.35.59%20PM.png)
